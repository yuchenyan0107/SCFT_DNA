# %%
from SCFT_functions import *

import numpy as np
import matplotlib.pyplot as plt

# %%
ns = 20

fa = 0.1
fb = 0.15
fc = 0.75

chain_interaction = np.zeros((3, ns+1))
chain_interaction[0, 0:int((ns+1)*fa)] += 1 # type A
chain_interaction[1, int((ns+1)*fa):int((ns+1)*fa+(ns+1)*fb)] += 1 # type B
chain_interaction[2, int((ns+1)*fa+(ns+1)*fb):] += 1 #type C

for i in range(3):
    plt.scatter(np.arange(ns+1), chain_interaction[i, :])

# %%
chi_bs = 30
chi_cs = 30
chi_polymer_s = np.array([0.5, chi_bs, chi_cs])

chi_N_polymer = 15
chi_matrix = chi_N_polymer * np.ones((chain_interaction.shape[0], chain_interaction.shape[0]))
np.fill_diagonal(chi_matrix, 0)

N = 20

nx = ny = nz = 64
initial_qsr = np.ones((nx, ny, nz))
L = 100 #dimension of the box

polymer = Scft(
    N = N,
    Lx=L, Ly=L,
    phibar=0.1, # volume fraction of polymer
    l_p=np.sqrt(N),
    n_seg=1, # contour length of polymer normalized from 0-1
    nx=nx, ny=ny,
    ns=ns,
    iterations=2000,
    error_tol=1e-12,
    chain_interaction=chain_interaction,
    self_avoiding=0,
    initial_qsr=initial_qsr / np.mean(initial_qsr),
    mixing_rate=0.05,
    chi_polymer_block = chi_matrix,
    chi_polymer_s = chi_polymer_s,
    PB = 3,
    close_boundary=True,
    D3 = True,
    Lz = L,
    nz = nz
)

# %%
wsr, qsr_initial, qsr_d_initial, diff = initialization(polymer)

# %%
wsr, phi, phi_blocks, qsr, qsr_d, diff = scft_loop(polymer, wsr, qsr_initial, qsr_d_initial, diff)
# Out:
#   6%|▌         | 115/2000 [00:05<01:32, 20.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 wsr, phi, phi_blocks, qsr, qsr_d, diff = scft_loop(polymer, wsr, qsr_initial, qsr_d_initial, diff)
#
# File C:\Softwares\scft-for-brached-and-confined-polymers-by-yuchen\SCFT_DNA\SCFT_functions\loop_function.py:79, in scft_loop(Scft_params, wsr, qsr_initial, qsr_d_initial, diff)
#      76 def scft_loop(Scft_params, wsr, qsr_initial, qsr_d_initial, diff):
#      78     for _ in tqdm(range(Scft_params.iterations)):
# ---> 79         wsr, phi, phi_blocks, qsr, qsr_d, err = scft_iteration(Scft_params, wsr, qsr_initial, qsr_d_initial)
#      80         diff.append(to_numpy(err))
#      82         qsr_initial = qsr_d[-1]
#
# File C:\Softwares\scft-for-brached-and-confined-polymers-by-yuchen\SCFT_DNA\SCFT_functions\loop_function.py:48, in scft_iteration(Scft_params, wsr, qsr_initial, qsr_d_initial)
#      46 if use_cupy == True:
#      47     qsr = solve_qsr_3d_neumann(Scft_params, wsr, qsr_initial, reverse = False)
# ---> 48     qsr_d_reverse = solve_qsr_3d_neumann(Scft_params, wsr, qsr_d_initial, reverse = True)
#      49 else:
#      50     qsr, qsr_d_reverse = Parallel(n_jobs=2, backend=backend)(
#      51         [
#      52             delayed(solve_qsr_3d_neumann)(Scft_params, wsr, qsr_initial, reverse = False),
#      53             delayed(solve_qsr_3d_neumann)(Scft_params, wsr, qsr_d_initial, reverse = True),
#      54         ]
#      55     )
#
# File C:\Softwares\scft-for-brached-and-confined-polymers-by-yuchen\SCFT_DNA\SCFT_functions\QSR_solvers.py:163, in solve_qsr_3d_neumann(Scft_params, wsr, qsr_initial, reverse)
#     160 xp.multiply(qsr_temp_s, exponent_W[which_block[s//Scft_params.PB]], out = q_real)
#     161 q_real_extend = _even_extension_3d(q_real, Scft_params.nx, Scft_params.ny, Scft_params.nz)
# --> 163 q_k  = xp.fft.fftn(q_real_extend)
#     164 xp.multiply(q_k, exp_L, out = q_k)
#     165 q_real_extend = xp.fft.ifftn(q_k).real
#
# File ~\anaconda3\Lib\site-packages\cupy\fft\_fft.py:788, in fftn(a, s, axes, norm)
#     785 from cupy.cuda import cufft
#     787 func = _default_fft_func(a, s, axes)
# --> 788 return func(a, s, axes, norm, cufft.CUFFT_FORWARD)
#
# File ~\anaconda3\Lib\site-packages\cupy\fft\_fft.py:591, in _fftn(a, s, axes, norm, direction, value_type, order, plan, overwrite_x, out)
#     589     else:
#     590         raise IndexError('list index out of range')
# --> 591 a = _convert_dtype(a, value_type)
#     593 if order == 'A':
#     594     if a.flags.f_contiguous:
#
# File ~\anaconda3\Lib\site-packages\cupy\fft\_fft.py:35, in _convert_dtype(a, value_type)
#      33 out_dtype = _output_dtype(a.dtype, value_type)
#      34 if out_dtype != a.dtype:
# ---> 35     a = a.astype(out_dtype)
#      36 return a
#
# KeyboardInterrupt:

# %%
plt.plot(diff)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import measure
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

def plot_multi_isosurface(densities, threshold_ratio=0.8, alpha=0.6, colormap='tab10'):
    """
    Plot isosurfaces for multiple 3D density arrays on the same axes.

    Parameters:
    - densities: list or array of shape (m, nx, ny, nz), where each element is a 3D density grid
    - threshold_ratio: float between 0 and 1; isosurface at this fraction of each component's max
    - alpha: float for surface transparency
    - colormap: name of a matplotlib colormap for distinct colors
    """
    # Ensure list of 3D arrays
    comps = list(densities)
    m = len(comps)
    cmap = plt.cm.get_cmap(colormap, m)

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    for i, density in enumerate(comps):
        level = threshold_ratio * density.max()
        verts, faces, normals, values = measure.marching_cubes(density, level=level)
        mesh = Poly3DCollection(verts[faces], alpha=alpha)
        mesh.set_facecolor(cmap(i))
        ax.add_collection3d(mesh)

    # Set axes limits based on the first component
    nx, ny, nz = comps[0].shape
    ax.set_xlim(0, nx)
    ax.set_ylim(0, ny)
    ax.set_zlim(0, nz)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    plt.tight_layout()
    plt.show()

    return

# %%
plot_multi_isosurface(to_numpy(phi_blocks), threshold_ratio=0.85)
# Out:
# C:\Users\19162\AppData\Local\Temp\ipykernel_49656\582000932.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(colormap, m)

# %%
import plotly.graph_objects as go

def plot_isosurfaces(
    density,
    top_fraction: float = 0.10,
    spacing=(1.0, 1.0, 1.0),
    component_names=None,
    save_html_path=None,
):
    vol = to_numpy(density)
    assert vol.ndim == 4, f"Expected (m, nx, ny, nz), got shape {vol.shape}"
    m, nx, ny, nz = vol.shape
    sx, sy, sz = spacing

    if component_names is None:
        component_names = [f"component {i}" for i in range(m)]
    else:
        assert len(component_names) == m, "component_names must match m"

    fig = go.Figure()

    for i in range(m):
        field = vol[i].astype(np.float64, copy=False)
        flat = field.ravel()
        nonzero = flat[flat > 0]
        base = nonzero if nonzero.size > 0 else flat
        if base.size == 0:
            continue

        iso_level = float(np.quantile(base, 1.0 - top_fraction))

        # Marching cubes at the chosen iso-level
        try:
            verts, faces, normals, values = measure.marching_cubes(
                volume=field, level=iso_level, spacing=(sx, sy, sz)
            )
        except TypeError:
            verts, faces, normals, values = measure.marching_cubes_lewiner(
                field, level=iso_level, spacing=(sx, sy, sz)
            )

        if verts.size == 0 or faces.size == 0:
            continue

        mesh = go.Mesh3d(
            x=verts[:, 0], y=verts[:, 1], z=verts[:, 2],
            i=faces[:, 0], j=faces[:, 1], k=faces[:, 2],
            name=component_names[i],
            opacity=0.5,
            flatshading=True,
            showscale=False,
        )
        fig.add_trace(mesh)

    fig.update_layout(
        title="Polymer components: densest-region iso-surfaces",
        scene=dict(xaxis_title="x", yaxis_title="y", zaxis_title="z", aspectmode="data"),
        showlegend=True,
    )

    if save_html_path is not None:
        fig.write_html(save_html_path, include_plotlyjs="cdn")
        return save_html_path
    return fig

# %%
plot_isosurfaces(
    to_numpy(phi_blocks),                 # shape (m, nx, ny, nz)
    top_fraction=0.03,       # densest fraction to enclose as an iso-surface
    spacing=(polymer.dx, polymer.dy, polymer.dz),    # voxel spacing for proper aspect ratio
    component_names=None,    # optional list of names per component
    save_html_path='isosurface_demo.html',     # optional: path to save interactive HTML
)
# Out:
# 'isosurface_demo.html'

# %%
qsr_decay = np.mean(qsr, axis = (1,2,3))
plt.plot(to_numpy(qsr_decay))
plt.yscale('log')
